# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("Hours and Scores.csv")

# %%
df.head()
df.shape
df
# Out:
#    Unnamed: 0  Hours  Scores
# 0      2.5,21    2.5      21
# 1      5.1,47    5.1      47
# 2      3.2,27    3.2      27
# 3      8.5,75    8.5      75
# 4      3.5,30    3.5      30
# 5      1.5,20    1.5      20
# 6      9.2,88    9.2      88
# 7      5.5,60    5.5      60
# 8      8.3,81    8.3      81
# 9      2.7,25    2.7      25
# 10     7.7,85    7.7      85
# 11     5.9,62    5.9      62
# 12     4.5,41    4.5      41
# 13     3.3,42    3.3      42
# 14     1.1,17    1.1      17
# 15     8.9,95    8.9      95
# 16     2.5,30    2.5      30
# 17     1.9,24    1.9      24
# 18     6.1,67    6.1      67
# 19     7.4,69    7.4      69
# 20     2.7,30    2.7      30
# 21     4.8,54    4.8      54
# 22     3.8,35    3.8      35
# 23     6.9,76    6.9      76
# 24     7.8,86    7.8      86

# %%
df.sort_values(by="Hours",ascending = True,axis = 0,inplace = True)

# %%
x = df["Hours"]
y = df["Scores"]
plt.plot(x,y,linestyle="--",marker="o",color="b")
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.title("Hours vs Scores")
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15200\1327771238.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# importing linear regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
# preparing the data
X = df[["Hours"]]
y = df[["Scores"]]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.33,random_state = 1)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# making a prediction
y_pred = model.predict(X_test)

# %%
# compute score
print(r2_score(y_test,y_pred))
# Out:
# 0.9439783469335068

# %%
plt.scatter(X_train,y_train,color = "green",label = "Actual(train)")
plt.plot(X_test,y_pred,color = "red",label = "Predicted")
plt.xlabel("Hours")
plt.xlabel("Score")
plt.title("hours vs score")
plt.legend()
plt.show()
